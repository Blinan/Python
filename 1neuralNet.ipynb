# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 32
#      28         final_outputs = list(net.query(inputs))
#      29         score += final_outputs.index(max(final_outputs))==all_values[0]
#      30     print('score = ', score/len(testing_data_list))
#      31     pass
# ---> 32 recogonizingHWDigit()
#
# Cell In[1], line 7, in recogonizingHWDigit()
#       3     hidden_nodes=100
#       4     output_nodes=10
#       5     lr=0.3
#       6
# ----> 7     net = neuralNetwork(input_nodes, hidden_nodes, output_nodes, lr)
#       8     training_data_file = open("D:\\Project\\dataset\\mnist_train.csv")
#       9     training_data_list = training_data_file.readlines()
#      10     training_data_file.close()
#
# NameError: name 'neuralNetwork' is not defined
